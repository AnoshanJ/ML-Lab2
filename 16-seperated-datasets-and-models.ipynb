# %% [markdown]
# # Parkinson's Disease Progression Prediction with TensorFlow Decision Forests
#
# This notebook walks you through how to train a baseline Random Forest model using TensorFlow Decision Forests on the AMP®-Parkinson's Disease Progression Prediction dataset made available for this competition. The model must predict MDS-UPDR scores, which measure progression in patients with Parkinson's disease.
#
# Roughly, the code will look as follows:
#
# ```
# import tensorflow_decision_forests as tfdf
# import pandas as pd
#
# dataset = pd.read_csv("project/dataset.csv")
# tf_dataset = tfdf.keras.pd_dataframe_to_tf_dataset(dataset, label="my_label")
#
# model = tfdf.keras.RandomForestModel()
# model.fit(tf_dataset)
#
# print(model.summary())
# ```
#
# This notebook will also show how to do some pre-processing of the data to make it easier for an ML models to learn from it.
#
# You'll also learn how to implement and use the evaluation metric used on this competition: SMAPE.
#
# Decision Forests are a family of tree-based models including Random Forests and Gradient Boosted Trees. They are the best place to start when working with tabular data, and will often outperform (or provide a strong baseline) before you begin experimenting with neural networks.

# %% [markdown]
# # Import the Required Libraries

# %%
import tensorflow as tf
import tensorflow_decision_forests as tfdf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
print("TensorFlow Decision Forests v" + tfdf.__version__)
print("TensorFlow v" + tf.__version__)
# Out:
# TensorFlow Decision Forests v1.2.0
# TensorFlow v2.11.0

# %% [markdown]
# # Load the Dataset

# %% [markdown]
# First, let us load the dataset using Pandas.

# %%
# Load a dataset into a Pandas DataFrame
train_proteins = pd.read_csv("/kaggle/input/amp-parkinsons-disease-progression-prediction/train_proteins.csv")
train_peptides = pd.read_csv("/kaggle/input/amp-parkinsons-disease-progression-prediction/train_peptides.csv")
train_clinical = pd.read_csv("/kaggle/input/amp-parkinsons-disease-progression-prediction/train_clinical_data.csv")

# %% [markdown]
# We will now examine each of these DataFrames in detail.

# %% [markdown]
# UPDRS is a rating instrument used to measure the the severity and progression of Parkinson’s disease in patients.
# When a patient visits the clinic, the clinic will record how the patient scored on 4 parts of  UPDRS test. This data can be found in `train_clinical`. The ratings for the the first 4 segments of UPDRS are available as `updrs_1`, `updrs_2`, `updrs_3` and `updrs_4` in `train_clinical`.
# Our goal is to train a model to predict these UPDRS ratings.

# %% [markdown]
# Let us examine the shape of `train_clinical` DataFrame.

# %%
print('clinical dataset shape:  ', train_clinical.shape)
# Out:
# clinical dataset shape:   (2615, 8)

# %% [markdown]
# The `train_clinical` data is composed of ***8* columns** and ***2615* entries**.  We can see all 8 dimensions of our dataset by printing out the first 5 entries using the following code:

# %%
# Display the first 5 examples
train_clinical.head(5)
# Out:
#   visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 0     55_0          55            0     10.0      6.0     15.0      NaN
# 1     55_3          55            3     10.0      7.0     25.0      NaN
# 2     55_6          55            6      8.0     10.0     34.0      NaN
# 3     55_9          55            9      8.0      9.0     30.0      0.0
# 4    55_12          55           12     10.0     10.0     41.0      0.0
#
#   upd23b_clinical_state_on_medication
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                  On
# 4                                  On

# %%
print(len(train_clinical.groupby(['patient_id'])))
for i in train_clinical.groupby(['patient_id']):
    print(i[0],(i[1]))
# Out:
# 248
# 55    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 0      55_0          55            0     10.0      6.0     15.0      NaN
# 1      55_3          55            3     10.0      7.0     25.0      NaN
# 2      55_6          55            6      8.0     10.0     34.0      NaN
# 3      55_9          55            9      8.0      9.0     30.0      0.0
# 4     55_12          55           12     10.0     10.0     41.0      0.0
# 5     55_18          55           18      7.0     13.0     38.0      0.0
# 6     55_24          55           24     16.0      9.0     49.0      0.0
# 7     55_30          55           30     14.0     13.0     49.0      0.0
# 8     55_36          55           36     17.0     18.0     51.0      0.0
# 9     55_42          55           42     12.0     20.0     41.0      0.0
# 10    55_48          55           48     17.0     16.0     52.0      0.0
# 11    55_54          55           54     12.0     18.0     51.0      0.0
# 12    55_60          55           60     23.0     21.0     56.0      0.0
#
#    upd23b_clinical_state_on_medication
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                   On
# 4                                   On
# 5                                   On
# 6                                   On
# 7                                   On
# 8                                   On
# 9                                   On
# 10                                  On
# 11                                  On
# 12                                  On
# 942    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 13    942_0         942            0      3.0      2.0     20.0      NaN
# 14    942_3         942            3      7.0      2.0     17.0      NaN
# 15    942_6         942            6      8.0      2.0     21.0      NaN
# 16   942_12         942           12      5.0      2.0     25.0      0.0
# 17   942_18         942           18      6.0      5.0     18.0      0.0
# 18   942_24         942           24      2.0      3.0     23.0      NaN
# 19   942_30         942           30      4.0      4.0     19.0      0.0
# 20   942_36         942           36      2.0      4.0     19.0      0.0
# 21   942_42         942           42      2.0      3.0     32.0      0.0
# 22   942_48         942           48      2.0      6.0     35.0      0.0
# 23   942_54         942           54      2.0      4.0     26.0      0.0
# 24   942_60         942           60      2.0      5.0     31.0      0.0
# 25   942_72         942           72      4.0      2.0     33.0      0.0
# 26   942_84         942           84      4.0      8.0     26.0      0.0
# 27   942_96         942           96      6.0      9.0     39.0      3.0
#
#    upd23b_clinical_state_on_medication
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 Off
# 26                                 Off
# 27                                 Off
# 1517    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 28   1517_0        1517            0     11.0      6.0     25.0      5.0
# 29   1517_6        1517            6     17.0      4.0     30.0      7.0
# 30  1517_12        1517           12     20.0     11.0     32.0      5.0
# 31  1517_18        1517           18     23.0     14.0     25.0      5.0
# 32  1517_24        1517           24     19.0     11.0     28.0      3.0
# 33  1517_30        1517           30     20.0     15.0     39.0     10.0
# 34  1517_36        1517           36     20.0     17.0     31.0      8.0
# 35  1517_42        1517           42     15.0     13.0     37.0      4.0
# 36  1517_48        1517           48     20.0     18.0     40.0      6.0
# 37  1517_60        1517           60     19.0     18.0     39.0     10.0
#
#    upd23b_clinical_state_on_medication
# 28                                  On
# 29                                  On
# 30                                  On
# 31                                  On
# 32                                  On
# 33                                 Off
# 34                                  On
# 35                                  On
# 36                                 Off
# 37                                 Off
# 1923    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 38   1923_0        1923            0      2.0      0.0      0.0      NaN
# 39   1923_6        1923            6      2.0      0.0      0.0      NaN
# 40  1923_12        1923           12      1.0      0.0      1.0      NaN
# 41  1923_18        1923           18      2.0      1.0      3.0      NaN
# 42  1923_24        1923           24      2.0      0.0      1.0      NaN
# 43  1923_30        1923           30      3.0      0.0      2.0      NaN
# 44  1923_36        1923           36      3.0      0.0      1.0      NaN
#
#    upd23b_clinical_state_on_medication
# 38                                 NaN
# 39                                 NaN
# 40                                 NaN
# 41                                 NaN
# 42                                 NaN
# 43                                 NaN
# 44                                 NaN
# 2660    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 45   2660_0        2660            0      2.0      0.0      0.0      NaN
# 46  2660_12        2660           12      0.0      0.0      1.0      NaN
# 47  2660_24        2660           24      2.0      0.0      1.0      NaN
# 48  2660_36        2660           36      8.0      0.0      2.0      NaN
# 49  2660_48        2660           48      6.0      0.0      0.0      NaN
# 50  2660_60        2660           60      5.0      0.0      1.0      NaN
#
#    upd23b_clinical_state_on_medication
# 45                                 NaN
# 46                                 NaN
# 47                                 NaN
# 48                                 NaN
# 49                                 NaN
# 50                                 NaN
# 3636    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 51   3636_0        3636            0      1.0      2.0      9.0      NaN
# 52   3636_3        3636            3      4.0      4.0     14.0      NaN
# 53   3636_6        3636            6     11.0     15.0     12.0      NaN
# 54   3636_9        3636            9      8.0      8.0     11.0      0.0
# 55  3636_12        3636           12      9.0     13.0     15.0      3.0
# 56  3636_18        3636           18      7.0      8.0      7.0      3.0
# 57  3636_24        3636           24     11.0      6.0     15.0      NaN
# 58  3636_30        3636           30      9.0      4.0      6.0      0.0
# 59  3636_36        3636           36     13.0      8.0      8.0      0.0
# 60  3636_42        3636           42     10.0      9.0     12.0      0.0
# 61  3636_48        3636           48     14.0     10.0      6.0      0.0
# 62  3636_54        3636           54     11.0     11.0     10.0      0.0
# 63  3636_60        3636           60     10.0     13.0      9.0      3.0
# 64  3636_72        3636           72      7.0     15.0     18.0      0.0
#
#    upd23b_clinical_state_on_medication
# 51                                 NaN
# 52                                 NaN
# 53                                 NaN
# 54                                  On
# 55                                  On
# 56                                  On
# 57                                 Off
# 58                                  On
# 59                                 Off
# 60                                  On
# 61                                 Off
# 62                                 Off
# 63                                 Off
# 64                                 Off
# 3863    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 65   3863_0        3863            0      8.0     13.0     36.0      4.0
# 66   3863_6        3863            6      9.0     10.0     38.0      0.0
# 67  3863_12        3863           12     11.0     11.0     29.0      7.0
# 68  3863_18        3863           18      9.0     12.0     41.0      5.0
# 69  3863_24        3863           24     11.0     18.0     28.0      6.0
# 70  3863_30        3863           30     12.0     16.0     32.0      7.0
# 71  3863_36        3863           36     11.0     11.0     28.0      4.0
# 72  3863_42        3863           42     15.0     16.0     25.0      5.0
# 73  3863_48        3863           48     17.0     22.0     22.0      5.0
#
#    upd23b_clinical_state_on_medication
# 65                                  On
# 66                                  On
# 67                                  On
# 68                                  On
# 69                                  On
# 70                                  On
# 71                                  On
# 72                                  On
# 73                                 NaN
# 4161    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 74   4161_0        4161            0      6.0      1.0      0.0      NaN
# 75   4161_3        4161            3      1.0      1.0      3.0      NaN
# 76   4161_6        4161            6      1.0      2.0      0.0      NaN
# 77   4161_9        4161            9      3.0      1.0      5.0      NaN
# 78  4161_12        4161           12      6.0      3.0     11.0      NaN
# 79  4161_18        4161           18      8.0      4.0      9.0      NaN
# 80  4161_24        4161           24      4.0      2.0      9.0      NaN
# 81  4161_30        4161           30     10.0      6.0     15.0      NaN
# 82  4161_36        4161           36      8.0     10.0     18.0      NaN
# 83  4161_42        4161           42     10.0     14.0     28.0      NaN
# 84  4161_48        4161           48      6.0     15.0     37.0      NaN
# 85  4161_54        4161           54      9.0     17.0     41.0      NaN
#
#    upd23b_clinical_state_on_medication
# 74                                 NaN
# 75                                 NaN
# 76                                 NaN
# 77                                 NaN
# 78                                 NaN
# 79                                 NaN
# 80                                 NaN
# 81                                 NaN
# 82                                 NaN
# 83                                 NaN
# 84                                 NaN
# 85                                 NaN
# 4172    visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 86   4172_0        4172            0      2.0      0.0      0.0      NaN
# 87  4172_12        4172           12      1.0      0.0      0.0      NaN
# 88  4172_24        4172           24      1.0      0.0      0.0      NaN
# 89  4172_36        4172           36      1.0      0.0      0.0      NaN
# 90  4172_48        4172           48      0.0      0.0      0.0      NaN
# 91  4172_60        4172           60      1.0      0.0      0.0      NaN
# 92  4172_84        4172           84      3.0      0.0      0.0      NaN
# 93  4172_96        4172           96      1.0      0.0      0.0      NaN
#
#    upd23b_clinical_state_on_medication
# 86                                 NaN
# 87                                 NaN
# 88                                 NaN
# 89                                 NaN
# 90                                 NaN
# 91                                 NaN
# 92                                 NaN
# 93                                 NaN
# 4923     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 94    4923_0        4923            0      2.0      3.0     21.0      0.0
# 95    4923_6        4923            6      6.0      3.0     23.0      0.0
# 96   4923_12        4923           12      6.0      2.0     21.0      0.0
# 97   4923_18        4923           18      7.0      3.0     21.0      3.0
# 98   4923_24        4923           24      4.0      2.0     19.0      2.0
# 99   4923_30        4923           30      7.0      4.0     25.0      4.0
# 100  4923_36        4923           36      7.0      3.0     13.0      2.0
# 101  4923_42        4923           42      6.0      6.0     19.0      3.0
# 102  4923_48        4923           48      7.0      4.0     11.0      4.0
# 103  4923_54        4923           54      7.0      5.0     15.0      3.0
# 104  4923_60        4923           60      9.0      4.0     17.0      2.0
#
#     upd23b_clinical_state_on_medication
# 94                                   On
# 95                                   On
# 96                                   On
# 97                                   On
# 98                                   On
# 99                                  Off
# 100                                  On
# 101                                  On
# 102                                  On
# 103                                  On
# 104                                  On
# 5027      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 105    5027_0        5027            0      1.0      0.0      0.0      NaN
# 106   5027_12        5027           12      1.0      0.0      0.0      NaN
# 107   5027_24        5027           24      2.0      0.0      0.0      NaN
# 108   5027_48        5027           48      2.0      0.0      0.0      NaN
# 109   5027_60        5027           60      3.0      0.0      0.0      NaN
# 110   5027_84        5027           84      1.0      0.0      1.0      NaN
# 111  5027_108        5027          108      5.0      0.0      1.0      NaN
#
#     upd23b_clinical_state_on_medication
# 105                                 NaN
# 106                                 NaN
# 107                                 NaN
# 108                                 NaN
# 109                                 NaN
# 110                                 NaN
# 111                                 NaN
# 5036     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 112   5036_0        5036            0      2.0      0.0      0.0      NaN
# 113  5036_12        5036           12      1.0      0.0      0.0      NaN
# 114  5036_24        5036           24      4.0      0.0      0.0      NaN
# 115  5036_36        5036           36      3.0      0.0      0.0      NaN
# 116  5036_48        5036           48      4.0      0.0      0.0      NaN
# 117  5036_60        5036           60      6.0      0.0      0.0      NaN
# 118  5036_72        5036           72      6.0      2.0      0.0      NaN
# 119  5036_84        5036           84      8.0      0.0      0.0      NaN
# 120  5036_96        5036           96      4.0      0.0      0.0      NaN
#
#     upd23b_clinical_state_on_medication
# 112                                 NaN
# 113                                 NaN
# 114                                 NaN
# 115                                 NaN
# 116                                 NaN
# 117                                 NaN
# 118                                 NaN
# 119                                 NaN
# 120                                 NaN
# 5178     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 121   5178_0        5178            0      9.0      1.0      3.0      NaN
# 122  5178_12        5178           12      1.0      0.0      4.0      NaN
# 123  5178_24        5178           24      4.0      0.0      1.0      NaN
# 124  5178_36        5178           36      2.0      0.0      2.0      NaN
# 125  5178_48        5178           48      1.0      0.0      2.0      NaN
# 126  5178_60        5178           60      3.0      0.0      2.0      NaN
# 127  5178_84        5178           84      3.0      0.0      4.0      NaN
# 128  5178_96        5178           96      7.0      0.0      2.0      NaN
#
#     upd23b_clinical_state_on_medication
# 121                                 NaN
# 122                                 NaN
# 123                                 NaN
# 124                                 NaN
# 125                                 NaN
# 126                                 NaN
# 127                                 NaN
# 128                                 NaN
# 5645      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 129    5645_0        5645            0     12.0      7.0     17.0      NaN
# 130    5645_3        5645            3      5.0      9.0     21.0      NaN
# 131    5645_6        5645            6      7.0     11.0     25.0      NaN
# 132   5645_12        5645           12      9.0      9.0     29.0      0.0
# 133   5645_18        5645           18     10.0     11.0     31.0      0.0
# 134   5645_24        5645           24     13.0     11.0     32.0      0.0
# 135   5645_30        5645           30     15.0     11.0     30.0      0.0
# 136   5645_36        5645           36     10.0     15.0     30.0      0.0
# 137   5645_42        5645           42     17.0     19.0     30.0      0.0
# 138   5645_48        5645           48     25.0     23.0     45.0      0.0
# 139   5645_54        5645           54     16.0     19.0     63.0      0.0
# 140   5645_60        5645           60     20.0     19.0     50.0      2.0
# 141   5645_72        5645           72     17.0     26.0     38.0      7.0
# 142   5645_84        5645           84     14.0     20.0     34.0      9.0
# 143   5645_96        5645           96     19.0     15.0     22.0      4.0
# 144  5645_108        5645          108     20.0     14.0     34.0      0.0
#
#     upd23b_clinical_state_on_medication
# 129                                 NaN
# 130                                 NaN
# 131                                 NaN
# 132                                 NaN
# 133                                 NaN
# 134                                 NaN
# 135                                 Off
# 136                                 Off
# 137                                 Off
# 138                                 Off
# 139                                 Off
# 140                                 Off
# 141                                 Off
# 142                                 Off
# 143                                 NaN
# 144                                 NaN
# 5742     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 145   5742_0        5742            0      5.0      7.0     38.0      NaN
# 146   5742_3        5742            3      5.0      8.0     43.0      NaN
# 147   5742_6        5742            6      6.0     13.0     56.0      NaN
# 148  5742_12        5742           12      6.0     17.0     46.0      0.0
# 149  5742_18        5742           18      6.0     18.0     46.0      0.0
# 150  5742_24        5742           24      6.0     18.0     51.0      0.0
# 151  5742_30        5742           30      5.0     18.0     49.0      0.0
# 152  5742_36        5742           36      7.0     20.0     51.0      0.0
# 153  5742_42        5742           42      7.0     20.0     54.0      0.0
#
#     upd23b_clinical_state_on_medication
# 145                                 NaN
# 146                                 NaN
# 147                                 NaN
# 148                                 Off
# 149                                  On
# 150                                 Off
# 151                                 Off
# 152                                  On
# 153                                  On
# 6054     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 154   6054_0        6054            0      7.0      5.0     17.0      NaN
# 155   6054_3        6054            3      5.0      7.0     17.0      NaN
# 156   6054_6        6054            6     12.0     10.0     17.0      NaN
# 157   6054_9        6054            9      7.0      8.0     24.0      NaN
# 158  6054_12        6054           12      5.0      7.0     25.0      NaN
# 159  6054_18        6054           18      6.0      4.0     20.0      NaN
# 160  6054_24        6054           24     13.0      9.0     16.0      0.0
# 161  6054_30        6054           30      7.0     10.0     19.0      0.0
# 162  6054_36        6054           36     10.0     11.0     35.0      0.0
# 163  6054_42        6054           42      8.0     14.0     34.0      0.0
# 164  6054_48        6054           48     11.0     14.0     33.0      0.0
# 165  6054_54        6054           54      9.0     14.0     34.0      0.0
# 166  6054_60        6054           60     14.0     15.0     36.0      0.0
# 167  6054_72        6054           72     14.0     14.0     43.0      0.0
# 168  6054_84        6054           84     17.0     14.0     52.0      4.0
#
#     upd23b_clinical_state_on_medication
# 154                                 NaN
# 155                                 NaN
# 156                                 NaN
# 157                                 NaN
# 158                                 NaN
# 159                                 NaN
# 160                                 NaN
# 161                                 NaN
# 162                                 NaN
# 163                                 NaN
# 164                                 NaN
# 165                                 NaN
# 166                                 NaN
# 167                                 Off
# 168                                 Off
# 6211     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 169   6211_0        6211            0      5.0     11.0      9.0      NaN
# 170   6211_3        6211            3      6.0      8.0     12.0      NaN
# 171   6211_6        6211            6      6.0     11.0     21.0      NaN
# 172  6211_12        6211           12      8.0      8.0     17.0      0.0
# 173  6211_18        6211           18     10.0      7.0     16.0      0.0
# 174  6211_24        6211           24      6.0      9.0     14.0      3.0
# 175  6211_30        6211           30      9.0     10.0     12.0      5.0
# 176  6211_36        6211           36      8.0      8.0     11.0      0.0
# 177  6211_42        6211           42      7.0      1.0      9.0      2.0
# 178  6211_48        6211           48     11.0     13.0     26.0      4.0
# 179  6211_54        6211           54      5.0      4.0     12.0      8.0
# 180  6211_60        6211           60      4.0      7.0     17.0      5.0
# 181  6211_72        6211           72      1.0      3.0      4.0      4.0
#
#     upd23b_clinical_state_on_medication
# 169                                 NaN
# 170                                 NaN
# 171                                 NaN
# 172                                 Off
# 173                                 Off
# 174                                 Off
# 175                                  On
# 176                                 Off
# 177                                  On
# 178                                 Off
# 179                                  On
# 180                                  On
# 181                                  On
# 6420     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 182   6420_0        6420            0      1.0      0.0      0.0      NaN
# 183  6420_12        6420           12      1.0      0.0      0.0      NaN
# 184  6420_24        6420           24      1.0      3.0      0.0      NaN
# 185  6420_36        6420           36      1.0      1.0      0.0      0.0
# 186  6420_48        6420           48      0.0      1.0      0.0      NaN
# 187  6420_60        6420           60      1.0      0.0      1.0      NaN
# 188  6420_96        6420           96      0.0      0.0      0.0      NaN
#
#     upd23b_clinical_state_on_medication
# 182                                 NaN
# 183                                 NaN
# 184                                 NaN
# 185                                 NaN
# 186                                 NaN
# 187                                 NaN
# 188                                 NaN
# 7051     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 189   7051_0        7051            0      4.0      8.0     18.0      NaN
# 190   7051_3        7051            3     10.0      9.0     18.0      NaN
# 191   7051_6        7051            6      6.0      6.0     21.0      0.0
# 192   7051_9        7051            9      8.0      9.0     24.0      0.0
# 193  7051_12        7051           12      5.0      8.0     29.0      0.0
# 194  7051_18        7051           18      6.0     10.0     27.0      0.0
# 195  7051_24        7051           24      5.0      7.0     16.0      0.0
# 196  7051_30        7051           30      5.0      9.0     17.0      0.0
# 197  7051_36        7051           36      9.0      9.0     34.0      0.0
# 198  7051_42        7051           42      9.0      8.0     30.0      5.0
# 199  7051_48        7051           48     11.0     10.0     39.0      0.0
# 200  7051_54        7051           54     10.0     13.0     28.0      4.0
# 201  7051_60        7051           60     12.0      9.0     21.0      0.0
# 202  7051_72        7051           72     14.0     13.0     46.0      2.0
# 203  7051_84        7051           84     21.0     22.0     53.0      2.0
#
#     upd23b_clinical_state_on_medication
# 189                                 NaN
# 190                                 NaN
# 191                                 NaN
# 192                                 NaN
# 193                                 NaN
# 194                                 Off
# 195                                 Off
# 196                                  On
# 197                                 Off
# 198                                  On
# 199                                 Off
# 200                                  On
# 201                                 Off
# 202                                 Off
# 203                                  On
# 7117      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 204    7117_0        7117            0      4.0      0.0      0.0      NaN
# 205   7117_12        7117           12      4.0      0.0      1.0      NaN
# 206   7117_24        7117           24      1.0      0.0      0.0      NaN
# 207   7117_36        7117           36      1.0      0.0      0.0      NaN
# 208   7117_48        7117           48      1.0      0.0      0.0      NaN
# 209   7117_60        7117           60      2.0      0.0      0.0      NaN
# 210   7117_84        7117           84      1.0      0.0      0.0      NaN
# 211   7117_96        7117           96      1.0      0.0      2.0      NaN
# 212  7117_108        7117          108      4.0      0.0      2.0      NaN
#
#     upd23b_clinical_state_on_medication
# 204                                 NaN
# 205                                 NaN
# 206                                 NaN
# 207                                 NaN
# 208                                 NaN
# 209                                 NaN
# 210                                 NaN
# 211                                 NaN
# 212                                 NaN
# 7151     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 213   7151_0        7151            0      0.0      0.0      0.0      NaN
# 214  7151_12        7151           12      2.0      0.0      0.0      NaN
# 215  7151_24        7151           24      0.0      0.0      0.0      NaN
# 216  7151_36        7151           36      0.0      0.0      0.0      NaN
# 217  7151_60        7151           60      1.0      0.0      0.0      NaN
# 218  7151_84        7151           84      1.0      0.0      1.0      NaN
# 219  7151_96        7151           96      0.0      0.0      2.0      NaN
#
#     upd23b_clinical_state_on_medication
# 213                                 NaN
# 214                                 NaN
# 215                                 NaN
# 216                                 NaN
# 217                                 NaN
# 218                                 NaN
# 219                                 NaN
# 7265     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 220   7265_0        7265            0     10.0     23.0     45.0      3.0
# 221   7265_6        7265            6     12.0     25.0     47.0      5.0
# 222  7265_12        7265           12     12.0     22.0     56.0      5.0
# 223  7265_18        7265           18     15.0     24.0     53.0      5.0
# 224  7265_24        7265           24     15.0     24.0     51.0      5.0
# 225  7265_30        7265           30     15.0     23.0     54.0      4.0
# 226  7265_36        7265           36     17.0     23.0     55.0      5.0
# 227  7265_42        7265           42     15.0     23.0     68.0      4.0
# 228  7265_48        7265           48     15.0     28.0     51.0      4.0
#
#     upd23b_clinical_state_on_medication
# 220                                  On
# 221                                  On
# 222                                  On
# 223                                  On
# 224                                  On
# 225                                  On
# 226                                  On
# 227                                 Off
# 228                                  On
# 7508     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 229   7508_0        7508            0      0.0      2.0      9.0      0.0
# 230   7508_6        7508            6      4.0      6.0     13.0      NaN
# 231  7508_12        7508           12      0.0      5.0     19.0      0.0
# 232  7508_18        7508           18      1.0      9.0     13.0      0.0
# 233  7508_24        7508           24      1.0      7.0     25.0      0.0
# 234  7508_30        7508           30      0.0      9.0     14.0      0.0
# 235  7508_36        7508           36      2.0     11.0     15.0      0.0
# 236  7508_42        7508           42      5.0      9.0     12.0      0.0
# 237  7508_48        7508           48      0.0      9.0     17.0      0.0
# 238  7508_54        7508           54      5.0     11.0     10.0      0.0
# 239  7508_60        7508           60      5.0     13.0     28.0      0.0
#
#     upd23b_clinical_state_on_medication
# 229                                 NaN
# 230                                 NaN
# 231                                 NaN
# 232                                  On
# 233                                 Off
# 234                                  On
# 235                                 Off
# 236                                  On
# 237                                 Off
# 238                                  On
# 239                                 Off
# 7568     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 240   7568_0        7568            0      4.0      0.0      0.0      NaN
# 241  7568_12        7568           12      8.0      0.0      3.0      NaN
# 242  7568_24        7568           24      3.0      0.0      0.0      NaN
# 243  7568_36        7568           36      8.0      0.0      5.0      NaN
# 244  7568_48        7568           48      7.0      0.0      3.0      NaN
# 245  7568_60        7568           60      5.0      1.0      0.0      NaN
#
#     upd23b_clinical_state_on_medication
# 240                                 NaN
# 241                                 NaN
# 242                                 NaN
# 243                                 NaN
# 244                                 NaN
# 245                                 NaN
# 7832     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 246   7832_0        7832            0      4.0      1.0     16.0      NaN
# 247   7832_3        7832            3      6.0      4.0     19.0      NaN
# 248   7832_6        7832            6      5.0      2.0     19.0      NaN
# 249   7832_9        7832            9      5.0      4.0     20.0      NaN
# 250  7832_12        7832           12      4.0      4.0     21.0      NaN
# 251  7832_18        7832           18      5.0      5.0      NaN      NaN
# 252  7832_24        7832           24      8.0      5.0     21.0      5.0
# 253  7832_30        7832           30      5.0      5.0     23.0      6.0
# 254  7832_36        7832           36      8.0      6.0     35.0      8.0
# 255  7832_42        7832           42      8.0      5.0     31.0      6.0
# 256  7832_48        7832           48      2.0      5.0     32.0      2.0
# 257  7832_54        7832           54      4.0      8.0     29.0      0.0
# 258  7832_60        7832           60      7.0      3.0     39.0      3.0
# 259  7832_84        7832           84      7.0      2.0     27.0      3.0
#
#     upd23b_clinical_state_on_medication
# 246                                 NaN
# 247                                 NaN
# 248                                 NaN
# 249                                 NaN
# 250                                 NaN
# 251                                 NaN
# 252                                 Off
# 253                                  On
# 254                                 Off
# 255                                  On
# 256                                 Off
# 257                                  On
# 258                                 Off
# 259                                  On
# 7886     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 260   7886_0        7886            0      4.0      4.0     10.0      NaN
# 261   7886_3        7886            3      4.0      4.0     18.0      NaN
# 262   7886_6        7886            6      9.0      6.0     15.0      NaN
# 263   7886_9        7886            9      5.0      6.0     26.0      0.0
# 264  7886_12        7886           12      6.0      4.0      9.0      0.0
# 265  7886_18        7886           18      8.0      5.0     22.0      0.0
# 266  7886_24        7886           24     10.0      8.0      6.0      0.0
# 267  7886_30        7886           30      9.0      3.0     18.0      0.0
# 268  7886_36        7886           36      7.0      4.0     11.0      0.0
# 269  7886_42        7886           42      6.0      3.0     20.0      0.0
# 270  7886_54        7886           54      5.0      5.0      6.0      0.0
# 271  7886_60        7886           60      5.0      4.0      5.0      3.0
# 272  7886_72        7886           72      9.0      7.0     10.0      0.0
# 273  7886_84        7886           84      9.0      6.0     13.0      6.0
#
#     upd23b_clinical_state_on_medication
# 260                                 NaN
# 261                                 NaN
# 262                                 NaN
# 263                                 NaN
# 264                                 Off
# 265                                 Off
# 266                                  On
# 267                                  On
# 268                                  On
# 269                                  On
# 270                                  On
# 271                                  On
# 272                                 Off
# 273                                 Off
# 8344     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 274   8344_0        8344            0      4.0      6.0     18.0      NaN
# 275   8344_3        8344            3      5.0      8.0     19.0      NaN
# 276   8344_6        8344            6      7.0     11.0     20.0      NaN
# 277   8344_9        8344            9     10.0     12.0     22.0      NaN
# 278  8344_12        8344           12      5.0     11.0     20.0      0.0
# 279  8344_18        8344           18      5.0     10.0     19.0      0.0
# 280  8344_24        8344           24      5.0     11.0     22.0      0.0
# 281  8344_30        8344           30      4.0     10.0     29.0      0.0
# 282  8344_36        8344           36      6.0     13.0     18.0      0.0
# 283  8344_42        8344           42      6.0     11.0     23.0      0.0
# 284  8344_48        8344           48      5.0     11.0     30.0      0.0
# 285  8344_54        8344           54      6.0     12.0     21.0      0.0
# 286  8344_60        8344           60      9.0     10.0     23.0      3.0
# 287  8344_72        8344           72      8.0     10.0     16.0      0.0
# 288  8344_84        8344           84     12.0     14.0     18.0      3.0
# 289  8344_96        8344           96     13.0     16.0     24.0      2.0
#
#     upd23b_clinical_state_on_medication
# 274                                 NaN
# 275                                 NaN
# 276                                 NaN
# 277                                 NaN
# 278                                 NaN
# 279                                  On
# 280                                 Off
# 281                                  On
# 282                                 Off
# 283                                  On
# 284                                 Off
# 285                                  On
# 286                                 Off
# 287                                  On
# 288                                 Off
# 289                                  On
# 8699     visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 290   8699_0        8699            0     17.0     13.0     11.0      4.0
# 291   8699_6        8699            6     21.0     13.0     14.0      0.0
# 292  8699_12        8699           12     13.0     15.0     12.0      0.0
# 293  8699_18        8699           18     12.0     14.0      9.0      0.0
# 294  8699_24        8699           24     11.0     10.0     13.0      2.0
# 295  8699_36        8699           36     12.0     15.0     16.0      1.0
# 296  8699_42        8699           42     15.0     16.0     17.0      2.0
#
#     upd23b_clinical_state_on_medication
# 290                                  On
# 291                                  On
# 292                                  On
# 293                                  On
# 294                                  On
# 295                                  On
# 296                                  On
# 10053      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 297   10053_0       10053            0      3.0      0.0     13.0      0.0
# 298   10053_6       10053            6      2.0      4.0      5.0      0.0
# 299  10053_12       10053           12      4.0      2.0      8.0      0.0
# 300  10053_18       10053           18      2.0      2.0      0.0      0.0
# 301  10053_24       10053           24      4.0      3.0      0.0      0.0
#
#     upd23b_clinical_state_on_medication
# 297                                 NaN
# 298                                 NaN
# 299                                 NaN
# 300                                 NaN
# 301                                 NaN
# 10138      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 302   10138_0       10138            0      8.0      6.0     15.0      0.0
# 303   10138_6       10138            6      2.0      5.0     15.0      0.0
# 304  10138_12       10138           12      3.0      6.0     31.0      0.0
# 305  10138_18       10138           18      6.0     11.0     25.0      1.0
# 306  10138_24       10138           24      4.0      7.0     19.0     10.0
# 307  10138_30       10138           30     10.0     10.0     20.0      5.0
# 308  10138_36       10138           36      5.0      2.0     11.0      0.0
#
#     upd23b_clinical_state_on_medication
# 302                                  On
# 303                                  On
# 304                                  On
# 305                                  On
# 306                                  On
# 307                                  On
# 308                                  On
# 10174      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 309   10174_0       10174            0      3.0      0.0      2.0      NaN
# 310  10174_12       10174           12      1.0      0.0      4.0      NaN
# 311  10174_24       10174           24      0.0      0.0      3.0      NaN
# 312  10174_36       10174           36      3.0      0.0      3.0      NaN
# 313  10174_48       10174           48      2.0      0.0      3.0      NaN
# 314  10174_60       10174           60      3.0      0.0      0.0      NaN
# 315  10174_84       10174           84      1.0      0.0      2.0      NaN
# 316  10174_96       10174           96      1.0      1.0      4.0      NaN
#
#     upd23b_clinical_state_on_medication
# 309                                 NaN
# 310                                 NaN
# 311                                 NaN
# 312                                 NaN
# 313                                 NaN
# 314                                 NaN
# 315                                 NaN
# 316                                 NaN
# 10541      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 317   10541_0       10541            0      2.0      2.0     13.0      NaN
# 318   10541_3       10541            3      1.0      1.0     11.0      NaN
# 319   10541_6       10541            6      1.0      3.0     12.0      NaN
# 320   10541_9       10541            9      3.0      6.0     19.0      NaN
# 321  10541_12       10541           12      3.0      3.0     27.0      NaN
# 322  10541_18       10541           18      3.0      5.0     16.0      NaN
# 323  10541_24       10541           24      7.0      5.0     28.0      NaN
# 324  10541_30       10541           30      5.0      2.0     21.0      0.0
# 325  10541_36       10541           36      6.0      5.0     20.0      4.0
# 326  10541_42       10541           42      2.0      6.0     21.0      2.0
# 327  10541_48       10541           48      4.0      3.0     26.0      0.0
# 328  10541_54       10541           54      5.0      4.0     26.0      3.0
# 329  10541_60       10541           60      5.0      3.0     29.0      3.0
# 330  10541_72       10541           72      4.0      7.0     32.0      3.0
# 331  10541_84       10541           84      5.0      9.0     38.0      3.0
#
#     upd23b_clinical_state_on_medication
# 317                                 NaN
# 318                                 NaN
# 319                                 NaN
# 320                                 NaN
# 321                                 NaN
# 322                                 NaN
# 323                                 NaN
# 324                                 Off
# 325                                 Off
# 326                                 Off
# 327                                 Off
# 328                                  On
# 329                                 Off
# 330                                 Off
# 331                                 Off
# 10715      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 332   10715_0       10715            0      2.0      6.0     21.0      NaN
# 333   10715_3       10715            3      4.0      5.0     40.0      NaN
# 334   10715_6       10715            6      0.0      3.0     33.0      NaN
# 335   10715_9       10715            9      2.0      8.0     37.0      NaN
# 336  10715_12       10715           12      2.0      2.0     32.0      0.0
# 337  10715_18       10715           18      1.0      2.0     21.0      0.0
# 338  10715_24       10715           24      2.0      6.0     27.0      0.0
# 339  10715_30       10715           30      6.0      6.0     34.0      0.0
# 340  10715_36       10715           36     11.0      9.0     37.0      0.0
# 341  10715_42       10715           42     11.0      1.0     27.0      0.0
# 342  10715_48       10715           48     14.0      5.0     35.0      0.0
# 343  10715_54       10715           54     11.0      9.0     31.0      0.0
# 344  10715_60       10715           60     11.0     10.0     35.0      0.0
# 345  10715_72       10715           72     18.0     12.0      NaN      0.0
#
#     upd23b_clinical_state_on_medication
# 332                                 NaN
# 333                                 NaN
# 334                                 NaN
# 335                                 NaN
# 336                                 NaN
# 337                                 NaN
# 338                                 NaN
# 339                                 NaN
# 340                                 NaN
# 341                                  On
# 342                                 Off
# 343                                  On
# 344                                 Off
# 345                                  On
# 10718      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 346   10718_0       10718            0      0.0      0.0      5.0      0.0
# 347   10718_6       10718            6      3.0      0.0      4.0      0.0
# 348  10718_12       10718           12      5.0      2.0      4.0      0.0
# 349  10718_18       10718           18      4.0      2.0      4.0      0.0
# 350  10718_24       10718           24      4.0      2.0      8.0      0.0
# 351  10718_30       10718           30      7.0      2.0      6.0      0.0
# 352  10718_36       10718           36      5.0      2.0     14.0      0.0
# 353  10718_42       10718           42      5.0      3.0      2.0      0.0
# 354  10718_48       10718           48      4.0      3.0      4.0      0.0
# 355  10718_54       10718           54      7.0      4.0      7.0      0.0
# 356  10718_60       10718           60      3.0      2.0      7.0      0.0
#
#     upd23b_clinical_state_on_medication
# 346                                 NaN
# 347                                 NaN
# 348                                 NaN
# 349                                 NaN
# 350                                 NaN
# 351                                 NaN
# 352                                 NaN
# 353                                 NaN
# 354                                 NaN
# 355                                 NaN
# 356                                 NaN
# 11459      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 357   11459_0       11459            0     17.0     13.0     30.0      0.0
# 358   11459_6       11459            6     15.0     11.0     25.0      0.0
# 359  11459_12       11459           12     14.0      8.0     26.0      0.0
# 360  11459_18       11459           18     15.0      9.0     35.0      0.0
# 361  11459_24       11459           24     15.0      6.0     26.0      0.0
# 362  11459_30       11459           30     14.0     11.0     29.0      5.0
# 363  11459_36       11459           36     14.0      6.0     41.0      4.0
# 364  11459_48       11459           48     13.0      9.0     18.0      0.0
# 365  11459_60       11459           60     13.0      8.0     15.0      1.0
#
#     upd23b_clinical_state_on_medication
# 357                                  On
# 358                                  On
# 359                                  On
# 360                                  On
# 361                                  On
# 362                                  On
# 363                                  On
# 364                                  On
# 365                                  On
# 11686      visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# ...
# 2491                                 NaN
# 2492                                 NaN
# 2493                                 NaN
# 2494                                  On
# 2495                                 NaN
# 2496                                 NaN
# 2497                                 NaN
# 61974       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2498   61974_0       61974            0      2.0      1.0      2.0      0.0
# 2499   61974_6       61974            6      1.0      0.0      2.0      0.0
# 2500  61974_12       61974           12      2.0      0.0      6.0      0.0
# 2501  61974_18       61974           18      1.0      0.0      7.0      0.0
# 2502  61974_24       61974           24      0.0      0.0      4.0      0.0
# 2503  61974_30       61974           30      2.0      1.0      3.0      0.0
# 2504  61974_36       61974           36      0.0      0.0      0.0      0.0
#
#      upd23b_clinical_state_on_medication
# 2498                                 NaN
# 2499                                 NaN
# 2500                                 NaN
# 2501                                 NaN
# 2502                                 NaN
# 2503                                 NaN
# 2504                                 NaN
# 62329       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2505   62329_0       62329            0     11.0      1.0      1.0      NaN
# 2506  62329_12       62329           12      9.0      1.0      0.0      NaN
# 2507  62329_24       62329           24      8.0      2.0      0.0      NaN
# 2508  62329_36       62329           36      6.0      1.0      0.0      NaN
# 2509  62329_48       62329           48     13.0      1.0      0.0      NaN
# 2510  62329_60       62329           60      8.0      6.0      0.0      NaN
#
#      upd23b_clinical_state_on_medication
# 2505                                 NaN
# 2506                                 NaN
# 2507                                 NaN
# 2508                                 NaN
# 2509                                 NaN
# 2510                                 NaN
# 62437       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2511   62437_0       62437            0      8.0      7.0     39.0      5.0
# 2512   62437_6       62437            6      8.0      6.0     30.0      0.0
# 2513  62437_12       62437           12      4.0      6.0     30.0      3.0
# 2514  62437_18       62437           18      8.0      5.0     22.0      3.0
# 2515  62437_24       62437           24     10.0      7.0     37.0      2.0
# 2516  62437_30       62437           30     11.0      7.0     28.0      4.0
# 2517  62437_36       62437           36     20.0      9.0     35.0      2.0
# 2518  62437_42       62437           42     10.0     11.0     29.0      0.0
# 2519  62437_48       62437           48      8.0      8.0     32.0      2.0
#
#      upd23b_clinical_state_on_medication
# 2511                                 Off
# 2512                                  On
# 2513                                 Off
# 2514                                 Off
# 2515                                 Off
# 2516                                  On
# 2517                                 Off
# 2518                                  On
# 2519                                 Off
# 62723       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2520   62723_0       62723            0      6.0      2.0      4.0      NaN
# 2521   62723_3       62723            3      7.0      2.0      8.0      1.0
# 2522   62723_6       62723            6      8.0      2.0      8.0      NaN
# 2523   62723_9       62723            9      7.0      3.0      7.0      1.0
# 2524  62723_12       62723           12      7.0      2.0      8.0      NaN
# 2525  62723_18       62723           18      9.0      5.0     14.0      NaN
# 2526  62723_24       62723           24      9.0      3.0      1.0      2.0
# 2527  62723_30       62723           30     10.0      4.0     11.0      4.0
# 2528  62723_36       62723           36      9.0      4.0      1.0      3.0
# 2529  62723_42       62723           42      8.0      3.0      3.0      5.0
# 2530  62723_48       62723           48      7.0      3.0      2.0      4.0
# 2531  62723_60       62723           60      7.0      3.0      3.0      4.0
# 2532  62723_72       62723           72      5.0      2.0      1.0      4.0
# 2533  62723_84       62723           84      7.0      3.0      6.0      3.0
#
#      upd23b_clinical_state_on_medication
# 2520                                 NaN
# 2521                                 NaN
# 2522                                 NaN
# 2523                                 NaN
# 2524                                 NaN
# 2525                                 NaN
# 2526                                  On
# 2527                                  On
# 2528                                  On
# 2529                                  On
# 2530                                  On
# 2531                                  On
# 2532                                  On
# 2533                                  On
# 62732       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2534   62732_0       62732            0     17.0      8.0     21.0      3.0
# 2535   62732_6       62732            6     23.0     10.0     33.0      4.0
# 2536  62732_12       62732           12     20.0      6.0      9.0      0.0
# 2537  62732_24       62732           24     20.0     16.0     16.0     13.0
#
#      upd23b_clinical_state_on_medication
# 2534                                  On
# 2535                                  On
# 2536                                  On
# 2537                                  On
# 62792       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2538   62792_0       62792            0      0.0      2.0     10.0      NaN
# 2539   62792_3       62792            3      0.0      3.0     10.0      NaN
# 2540   62792_6       62792            6      0.0      3.0      7.0      NaN
# 2541   62792_9       62792            9      1.0      2.0      9.0      0.0
# 2542  62792_12       62792           12      0.0      2.0      6.0      0.0
# 2543  62792_18       62792           18      0.0      3.0      3.0      0.0
# 2544  62792_24       62792           24      1.0      3.0      5.0      0.0
# 2545  62792_36       62792           36      1.0      3.0      4.0      0.0
# 2546  62792_48       62792           48      1.0      4.0     12.0      3.0
# 2547  62792_60       62792           60      2.0      6.0     13.0      0.0
# 2548  62792_72       62792           72      1.0      6.0     14.0      3.0
# 2549  62792_84       62792           84      2.0      5.0     21.0      3.0
#
#      upd23b_clinical_state_on_medication
# 2538                                 NaN
# 2539                                 NaN
# 2540                                 NaN
# 2541                                  On
# 2542                                  On
# 2543                                  On
# 2544                                  On
# 2545                                  On
# 2546                                  On
# 2547                                  On
# 2548                                  On
# 2549                                  On
# 63875       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2550   63875_0       63875            0      3.0      2.0      4.0      0.0
# 2551   63875_6       63875            6      2.0      0.0      0.0      0.0
# 2552  63875_12       63875           12      0.0      1.0      0.0      0.0
# 2553  63875_18       63875           18      4.0      2.0      0.0      0.0
# 2554  63875_24       63875           24      6.0      1.0      0.0      0.0
# 2555  63875_30       63875           30      5.0      1.0      1.0      0.0
# 2556  63875_36       63875           36      4.0      1.0      1.0      0.0
# 2557  63875_42       63875           42      4.0      1.0      1.0      0.0
# 2558  63875_48       63875           48      3.0      0.0      2.0      0.0
#
#      upd23b_clinical_state_on_medication
# 2550                                 NaN
# 2551                                 NaN
# 2552                                 NaN
# 2553                                 NaN
# 2554                                 NaN
# 2555                                 NaN
# 2556                                 NaN
# 2557                                 NaN
# 2558                                 NaN
# 63889       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2559   63889_0       63889            0      7.0      3.0     30.0      0.0
# 2560  63889_12       63889           12      8.0     10.0     21.0      3.0
# 2561  63889_18       63889           18      8.0      6.0      3.0      NaN
# 2562  63889_24       63889           24      8.0      2.0      7.0      2.0
# 2563  63889_30       63889           30      8.0      4.0     17.0      0.0
# 2564  63889_36       63889           36      8.0      3.0     18.0      1.0
# 2565  63889_42       63889           42      5.0      5.0     27.0      1.0
# 2566  63889_48       63889           48      5.0      8.0     10.0      2.0
# 2567  63889_54       63889           54      5.0      9.0     26.0      3.0
# 2568  63889_60       63889           60      6.0      5.0     28.0      2.0
#
#      upd23b_clinical_state_on_medication
# 2559                                 Off
# 2560                                 Off
# 2561                                 NaN
# 2562                                  On
# 2563                                 Off
# 2564                                 Off
# 2565                                 Off
# 2566                                  On
# 2567                                  On
# 2568                                 Off
# 64669       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2569   64669_0       64669            0     12.0     14.0     27.0      NaN
# 2570   64669_3       64669            3     15.0     16.0     29.0      NaN
# 2571   64669_6       64669            6     17.0     20.0     33.0      NaN
# 2572   64669_9       64669            9     12.0     16.0     17.0      0.0
# 2573  64669_12       64669           12     12.0      9.0     17.0      0.0
# 2574  64669_18       64669           18     15.0     13.0     20.0      0.0
# 2575  64669_24       64669           24     19.0     17.0     25.0      0.0
# 2576  64669_30       64669           30     20.0     13.0     38.0      0.0
# 2577  64669_36       64669           36     23.0     18.0     53.0      0.0
# 2578  64669_42       64669           42     20.0     18.0     49.0      0.0
# 2579  64669_48       64669           48     18.0     18.0     49.0      0.0
# 2580  64669_54       64669           54     15.0     16.0     48.0      0.0
# 2581  64669_60       64669           60     15.0     15.0     38.0      0.0
# 2582  64669_72       64669           72     15.0     19.0     39.0      0.0
# 2583  64669_84       64669           84     16.0     15.0     36.0      0.0
#
#      upd23b_clinical_state_on_medication
# 2569                                 NaN
# 2570                                 NaN
# 2571                                 NaN
# 2572                                  On
# 2573                                  On
# 2574                                  On
# 2575                                  On
# 2576                                  On
# 2577                                 Off
# 2578                                  On
# 2579                                 Off
# 2580                                  On
# 2581                                 Off
# 2582                                  On
# 2583                                  On
# 64674       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2584   64674_0       64674            0      5.0      1.0     13.0      NaN
# 2585   64674_3       64674            3      5.0      2.0     14.0      NaN
# 2586   64674_6       64674            6     11.0      7.0     20.0      NaN
# 2587   64674_9       64674            9     10.0      6.0     19.0      NaN
# 2588  64674_12       64674           12      9.0      9.0     18.0      NaN
# 2589  64674_18       64674           18      3.0      6.0     29.0      NaN
# 2590  64674_24       64674           24     12.0     12.0     26.0      NaN
# 2591  64674_30       64674           30     12.0     18.0     48.0      NaN
# 2592  64674_36       64674           36     11.0     18.0     44.0      1.0
# 2593  64674_42       64674           42      5.0     18.0     48.0      2.0
# 2594  64674_48       64674           48     11.0     17.0     46.0      1.0
# 2595  64674_54       64674           54      9.0     14.0     57.0      3.0
# 2596  64674_60       64674           60     14.0     13.0     45.0      3.0
# 2597  64674_72       64674           72     10.0     13.0     53.0      4.0
# 2598  64674_84       64674           84     11.0     15.0     45.0      4.0
# 2599  64674_96       64674           96     10.0     19.0     60.0      6.0
#
#      upd23b_clinical_state_on_medication
# 2584                                 NaN
# 2585                                 NaN
# 2586                                 NaN
# 2587                                 NaN
# 2588                                 NaN
# 2589                                 NaN
# 2590                                 NaN
# 2591                                 NaN
# 2592                                 NaN
# 2593                                 NaN
# 2594                                  On
# 2595                                  On
# 2596                                 Off
# 2597                                 Off
# 2598                                 Off
# 2599                                 Off
# 65043       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 2600   65043_0       65043            0      2.0      6.0     16.0      NaN
# 2601   65043_3       65043            3      2.0     11.0     19.0      NaN
# 2602   65043_6       65043            6      3.0      6.0     19.0      NaN
# 2603   65043_9       65043            9      2.0      7.0     11.0      0.0
# 2604  65043_12       65043           12      4.0      7.0     14.0      0.0
# 2605  65043_18       65043           18      6.0      7.0     13.0      0.0
# 2606  65043_24       65043           24      4.0      8.0      NaN      0.0
# 2607  65043_30       65043           30      3.0      4.0      4.0      0.0
# 2608  65043_36       65043           36      2.0      7.0      5.0      0.0
# 2609  65043_42       65043           42      9.0     10.0     15.0      0.0
# 2610  65043_48       65043           48      7.0      6.0     13.0      0.0
# 2611  65043_54       65043           54      4.0      8.0     11.0      1.0
# 2612  65043_60       65043           60      6.0      6.0     16.0      1.0
# 2613  65043_72       65043           72      3.0      9.0     14.0      1.0
# 2614  65043_84       65043           84      7.0      9.0     20.0      3.0
#
#      upd23b_clinical_state_on_medication
# 2600                                 NaN
# 2601                                 NaN
# 2602                                 NaN
# 2603                                  On
# 2604                                 Off
# 2605                                 Off
# 2606                                 NaN
# 2607                                 Off
# 2608                                 Off
# 2609                                 Off
# 2610                                 Off
# 2611                                 Off
# 2612                                 Off
# 2613                                 Off
# 2614                                 Off

# %% [markdown]
# The clinic will also record the patient's **NPX**(Normalized Protein eXpression) value for all the proteins relevant to Parkinson's disease during each visit. **NPX** is nothing but the value representing the protein concentration in shells. This data is available in the `train_proteins` DataFrame.
#
# Let us examine the shape of `train_proteins` DataFrame.

# %%
print('proteins dataset shape:  ', train_proteins.shape)
# Out:
# proteins dataset shape:   (232741, 5)

# %% [markdown]
# The `train_proteins` data is composed of ***5* columns** and ***232741* entries**. We can see all 5 dimensions of our dataset by printing out the first 5 entries using the following code:

# %%
# Display the first 5 examples
train_proteins.head(5)
# Out:
#   visit_id  visit_month  patient_id UniProt       NPX
# 0     55_0            0          55  O00391   11254.3
# 1     55_0            0          55  O00533  732430.0
# 2     55_0            0          55  O00584   39585.8
# 3     55_0            0          55  O14498   41526.9
# 4     55_0            0          55  O14773   31238.0

# %% [markdown]
# Proteins are long molecules made up of multiple peptides. The clinic will record the **Peptide Abundance** of each peptide in proteins relevant to Parkinson's disease. It shows the peptide concentration, similar to NPX for proteins.  This data can be found in the `train_peptides` DataFrame.
#
# Let us examine the shape of the `train_peptides` DataFrame.

# %%
print('peptides dataset shape:  ', train_peptides.shape)
# Out:
# peptides dataset shape:   (981834, 6)

# %% [markdown]
# The **train_peptides** data is composed of ***6* columns** and ***981834* entries**. We can see all 6 dimensions of our dataset by printing out the first 5 entries using the following code:

# %%
# Display the first 5 examples
train_peptides.head(5)
# Out:
#   visit_id  visit_month  patient_id UniProt  \
# 0     55_0            0          55  O00391
# 1     55_0            0          55  O00533
# 2     55_0            0          55  O00533
# 3     55_0            0          55  O00533
# 4     55_0            0          55  O00533
#
#                                   Peptide  PeptideAbundance
# 0                           NEQEQPLGQWHLS           11254.3
# 1                             GNPEPTFSWTK          102060.0
# 2                         IEIPSSVQQVPTIIK          174185.0
# 3  KPQSAVYSTGSNGILLC(UniMod_4)EAEGEPQPTIK           27278.9
# 4                            SMEQNGPGLEYR           30838.7

# %% [markdown]
# # Plotting clinical data
#
# We will pick a random `patient_id` and plot the target label values(`updrs_1`, `updrs_2`, `updrs_3`, `updrs_4`) of the patient against each month(`visit_month`).

# %%
# Fetch data for patient with id 1517
plot_df = train_clinical[train_clinical["patient_id"]==1517]
fig, ax = plt.subplots(1, 1)

ax.plot(plot_df['visit_month'], plot_df['updrs_1'], marker='o', color="blue", label="updrs_1", linestyle="-")
ax.plot(plot_df['visit_month'], plot_df['updrs_2'], marker='o', color="red", label="updrs_2", linestyle="-")
ax.plot(plot_df['visit_month'], plot_df['updrs_3'], marker='o', color="green", label="updrs_3", linestyle="-")
ax.plot(plot_df['visit_month'], plot_df['updrs_4'], marker='o', color="orange", label="updrs_4", linestyle="-")

ax.legend()
plt.show()

# %% [markdown]
# # Plotting protein data
#
#
# We will pick a random `patient_id` and plot the first 40 Protein entries(`UniProt`) of the patient and their NPX value against patient's visit month(`visit_month`).

# %%
pro_plot_df = train_proteins[train_proteins["patient_id"]==1517]
protein_list = pro_plot_df['UniProt'].unique()
protein_list = protein_list[:40]
pro_plot_df = pro_plot_df[pro_plot_df['UniProt'].isin(protein_list)]
unique_month = pro_plot_df['visit_month'].unique()
unique_month.sort()
p_len = len(unique_month)

pro_plot_df['visit_month'].unique()
n_rows = math.ceil(p_len/2)
figure, axis = plt.subplots(n_rows, 2, figsize=(15, n_rows*6))
plt.subplots_adjust(hspace=0.5, wspace=0.3)

for i, month in enumerate(unique_month):
    row = i//2
    col = i % 2
    plot_df = pro_plot_df[pro_plot_df['visit_month']==month]
    bp = sns.barplot(ax=axis[row, col], x=plot_df['UniProt'], y=plot_df['NPX'])
    #bp.set(xticklabels=[])
    bp.set_xticklabels(bp.get_xticklabels(), rotation=90, size = 7)
    axis[row, col].set_title('visit_month ' + str(month))
plt.show()

# %% [markdown]
# # Prepare the dataset
#
# We have to predict the ratings for the the first 4 segments of UPDRS `updrs_1`, `updrs_2`, `updrs_3` and `updrs_4` that is likely to be recorded by the clinic during a patient visit. Hence these are our labels.

# %% [markdown]
# We will now prepare the dataset for training models to predict the 4 labels.

# %% [markdown]
# To predict the target labels(`updrs_1`, `updrs_2`, `updrs_3`, `updrs_4`) for a given visit, we will use the recorded protein and peptide data of the patient during that visit.
#
# First we will group the rows in `train_proteins` data by visit ids (`visit id`) and protein ids (`UniProt`). Then we will replace the`NPX` values of each row in a group with the mean of the `NPX` values of all rows in that group.
#
# Similarly we will group the rows in `train_peptides` data by their visit ids(`visit_id`) and peptide ids(`Peptide`). Then we will replace the `PeptideAbundance` values of each row in a group with the mean of the `PeptideAbundance` values of all rows in that group.
#
# Following figure shows the working of Pandas groupby function.

# %% [markdown]
# ![group.png](attachment:1446775a-0b8a-4e72-80f1-b200a7b056be.png)
#
# This image was taken from [https://pandas.pydata.org](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %% [markdown]
# Now we will spread the rows of the grouped datasets into columns. For this we will use the Pandas pivot function.
#
# Below is a simple explanation for how the pivoting works.

# %% [markdown]
# ![pivotn.png](attachment:3abea96f-0f65-432c-9175-ccf93944c546.png)
#
# This image was taken from [https://pandas.pydata.org](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %% [markdown]
# The Protein dataset is pivoted such that unique values of `visit_id` become the indices and the values of `UniProt1` in the dataset become columns. For each visit(row), the `NPX` values corresponding to the different`UniProt1` values recorded for that visit are captured in the columns.
#
# The Peptipe dataset is pivoted such that unique values of `visit_id` become the indices and the values of `Peptide` in the dataset become columns. For each visit(row), the `PeptideAbundance` values corresponding to the different`Peptide` values recorded for that visit are captured in the columns.

# %% [markdown]
# We will now merge the pivoted peptide dataset with the pivoted protein dataset on `visit_id`.
#
# The figure shown below illustrates the logic behind Pandas merge function.

# %% [markdown]
# ![merge.png](attachment:38bb40a3-dca5-4ab4-aef8-c5293b99faaf.png)
#
# This image was taken from [https://pandas.pydata.org](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %% [markdown]
# In this notebook, we will let TensorFlow Decision Forests handle the missing values in the numerical columns.

# %%
# Function to prepare dataset with all the steps mentioned above:
def prepare_dataset(train_proteins, train_peptides):
    # Step 1: Grouping 
    df_protein_grouped = train_proteins.groupby(['visit_id','UniProt'])['NPX'].mean().reset_index()
    df_peptide_grouped = train_peptides.groupby(['visit_id','Peptide'])['PeptideAbundance'].mean().reset_index()
    
    # Step 2: Pivoting
    df_protein = df_protein_grouped.pivot(index='visit_id',columns = 'UniProt', values = 'NPX').rename_axis(columns=None).reset_index()
    df_peptide = df_peptide_grouped.pivot(index='visit_id',columns = 'Peptide', values = 'PeptideAbundance').rename_axis(columns=None).reset_index()
    
    # Step 3: Merging
    pro_pep_df = df_protein.merge(df_peptide, on = ['visit_id'], how = 'left')
    
    return pro_pep_df

# %%
pro_pep_df = prepare_dataset(train_proteins, train_peptides)

# %% [markdown]
# # Basic exploration of the prepared dataset

# %%
pro_pep_df.shape
# Out:
# (1113, 1196)

# %% [markdown]
# Our feature engineered dataset is composed of 1196 columns and 1113 entries.
#
# Let us print out the first 5 entries using the following code:

# %%
# Display the first 5 examples
pro_pep_df.head(5)
# Out:
#    visit_id    O00391    O00533   O00584   O14498    O14773   O14791  \
# 0   10053_0   9104.27  402321.0      NaN      NaN   7150.57  2497.84
# 1  10053_12  10464.20  435586.0      NaN      NaN       NaN      NaN
# 2  10053_18  13235.70  507386.0  7126.96  24525.7       NaN  2372.71
# 3  10138_12  12600.20  494581.0  9165.06  27193.5  22506.10  6015.90
# 4  10138_24  12003.20  522138.0  4498.51  17189.8  29112.40  2665.15
#
#      O15240   O15394    O43505  ...  YSLTYIYTGLSK  YTTEIIK  YVGGQEHFAHLLILR  \
# 0   83002.9  15113.6  167327.0  ...      202274.0      NaN        4401830.0
# 1  197117.0  15099.1  164268.0  ...      201009.0      NaN        5001750.0
# 2  126506.0  16289.6  168107.0  ...      220728.0      NaN        5424380.0
# 3  156313.0  54546.4  204013.0  ...      188362.0  9433.71        3900280.0
# 4  151169.0  52338.1  240892.0  ...      206187.0  6365.15        3521800.0
#
#    YVM(UniMod_35)LPVADQDQC(UniMod_4)IR  YVMLPVADQDQC(UniMod_4)IR  \
# 0                              77482.6                  583075.0
# 1                              36745.3                  355643.0
# 2                              39016.0                  496021.0
# 3                              48210.3                  328482.0
# 4                              69984.6                  496737.0
#
#    YVNKEIQNAVNGVK  YWGVASFLQK  YYC(UniMod_4)FQGNQFLR  YYTYLIMNK  YYWGGQYTWDMAK
# 0         76705.7    104260.0               530223.0        NaN        7207.30
# 1         92078.1    123254.0               453883.0    49281.9       25332.80
# 2         63203.6    128336.0               447505.0    52389.1       21235.70
# 3         89822.1    129964.0               552232.0    65657.8        9876.98
# 4         80919.3    111799.0                    NaN    56977.6        4903.09
#
# [5 rows x 1196 columns]

# %%
pro_pep_df.describe()
# Out:
#              O00391        O00533        O00584        O14498        O14773  \
# count    764.000000  1.112000e+03   1100.000000   1032.000000   1047.000000
# mean   11641.264435  5.111649e+05  26505.529157  27305.934884  17688.295406
# std     2817.003530  2.357357e+05  10705.152540   8446.187506   7166.325369
# min      873.778000  5.971820e+04    591.103000   8945.340000   2811.120000
# 25%     9736.857500  3.490590e+05  19941.075000  21123.650000  12920.050000
# 50%    11546.400000  4.834425e+05  26529.700000  26624.000000  17399.600000
# 75%    13383.025000  6.485572e+05  33222.800000  32459.275000  22077.050000
# max    21361.800000  1.806980e+06  66252.400000  65347.900000  49695.600000
#
#             O14791         O15240         O15394         O43505  \
# count   942.000000    1113.000000    1050.000000    1110.000000
# mean   3004.990691  126151.780054   50773.474638  195599.363694
# std    1142.159575   72748.393517   21382.028764   79739.704279
# min     336.517000   10717.400000    5806.840000   29740.900000
# 25%    2189.087500   70560.600000   37008.975000  142054.500000
# 50%    2865.460000  116900.000000   50375.800000  185616.000000
# 75%    3593.147500  164947.000000   63446.700000  239731.500000
# max    9352.640000  538862.000000  137369.000000  766591.000000
#
#               O60888  ...   YSLTYIYTGLSK       YTTEIIK  YVGGQEHFAHLLILR  \
# count    1079.000000  ...    1100.000000    994.000000     1.022000e+03
# mean   145382.047368  ...  215246.833636   9015.134433     3.937256e+06
# std     58028.089713  ...   50727.227704   3127.061637     1.677710e+06
# min      8358.080000  ...   12164.300000    258.249000     1.624640e+05
# 25%    103983.000000  ...  186658.250000   6899.805000     2.895622e+06
# 50%    136452.000000  ...  217430.500000   8604.345000     3.671010e+06
# 75%    177451.000000  ...  246423.500000  10612.775000     4.710635e+06
# max    427084.000000  ...  409939.000000  27670.500000     1.385550e+07
#
#        YVM(UniMod_35)LPVADQDQC(UniMod_4)IR  YVMLPVADQDQC(UniMod_4)IR  \
# count                           977.000000              1.091000e+03
# mean                          67866.452927              6.110779e+05
# std                           61176.002825              5.047422e+05
# min                             884.260000              7.494660e+03
# 25%                           30997.900000              2.929505e+05
# 50%                           52576.900000              4.702450e+05
# 75%                           85369.600000              7.592380e+05
# max                          712856.000000              3.984710e+06
#
#        YVNKEIQNAVNGVK     YWGVASFLQK  YYC(UniMod_4)FQGNQFLR      YYTYLIMNK  \
# count     1111.000000    1089.000000            1105.000000    1030.000000
# mean     92581.223041  125937.993436          471554.596652   47068.709311
# std      30138.957433   38696.448657          131150.715245   13689.667117
# min        869.898000     991.452000           11371.200000    6362.490000
# 25%      70508.150000  100691.000000          384902.000000   37752.375000
# 50%      88918.600000  123588.000000          463382.000000   45503.150000
# 75%     110140.000000  149597.000000          549455.000000   54748.350000
# max     251526.000000  264224.000000          948416.000000  107220.000000
#
#        YYWGGQYTWDMAK
# count      865.00000
# mean     21072.04823
# std      10360.59380
# min        868.90300
# 25%      14249.90000
# 50%      20390.90000
# 75%      27031.90000
# max      70020.80000
#
# [8 rows x 1195 columns]

# %% [markdown]
# Now let us write a function to split the dataset into train and test datasets. This will be used in the training loop.

# %%
def split_dataset(dataset, test_ratio=0.20):
  test_indices = np.random.rand(len(dataset)) < test_ratio
  return dataset[~test_indices], dataset[test_indices]

# %% [markdown]
# # Select a Model
# There are several tree-based models for you to choose from.
#
# - RandomForestModel
# - GradientBoostedTreesModel
# - CartModel
# - DistributedGradientBoostedTreesModel
#
# We can list all the available models in TensorFlow Decision Forests using the following code:

# %%
tfdf.keras.get_all_models()
# Out:
# [tensorflow_decision_forests.keras.RandomForestModel,
#  tensorflow_decision_forests.keras.GradientBoostedTreesModel,
#  tensorflow_decision_forests.keras.CartModel,
#  tensorflow_decision_forests.keras.DistributedGradientBoostedTreesModel]

# %% [markdown]
# To get started, we'll work with a Random Forest. This is the most well-known of the Decision Forest training algorithms.
#
# A Random Forest is a collection of decision trees, each trained independently on a random subset of the training dataset (sampled with replacement). The algorithm is unique in that it is robust to overfitting, and easy to use.

# %% [markdown]
# # How can I configure a tree-based model?
#
# TensorFlow Decision Forests provides good defaults for you (e.g., the top ranking hyperparameters on our benchmarks, slightly modified to run in reasonable time). If you would like to configure the learning algorithm, you will find many options you can explore to get the highest possible accuracy.
#
# You can select a template and/or set parameters as follows:
#
# ```rf = tfdf.keras.RandomForestModel(hyperparameter_template="benchmark_rank1", task=tfdf.keras.Task.REGRESSION)```
#
# Read more [here](https://www.tensorflow.org/decision_forests/api_docs/python/tfdf/keras/RandomForestModel).

# %% [markdown]
# Before training the model, let us write a function to calculate the scoring metric of the competition.

# %% [markdown]
# # sMAPE
#
# The scoring metric for this competition is sMAPE(symmetric Mean Absolute Percentage Error). In MAPE(Mean Absolute Percentage Error) we calculate the sum of absolute value of the forecast errors, divided by the actual values for each period([source](https://en.wikipedia.org/wiki/Mean_absolute_percentage_error)).
#
# Difference between MAPE and sMAPE is that sMAPE has both a lower bound and an upper bound.
#
#
# You can read more about sMAPE [here](https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error).
#
# Since TensorFlow Datasets doesn't have a bultin function to calculate sMAPE metric yet, we will write a custom function to calculate sMAPE.

# %%
def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

# %% [markdown]
# # Training
#
# We will train a model each to predict the first 4 segments of the UPDRS, `updrs_1`, `updrs_2`, `updrs_3` and `updrs_4`. Thus we we will be training 4 models, one for each label.
#
# We need to provide a few data structures to our training loop to store the trained models, sMAPE scores and mse scores for the trained models.
#
# We will create these using the following code:

# %%
# Create an empty dictionary to store the models trained for each label.
model_dict = {}

# Create an empty dictionary to store the mse score of the models trained for each label.
mse_dict = {}

# Create an empty dictionary to store the sMAPE scores of the models trained for each label.
smape_dict = {}

# %% [markdown]
# Next, we will create a feature list with names of the columns we will use for training the model. We will avoid the column `visit_id` and add column the `visit_month`

# %%
FEATURES = [i for i in pro_pep_df.columns if i not in ["visit_id"]]
FEATURES.append("visit_month")

# %% [markdown]
# Now let us train the models.

# %%
# List of target labels to loop through and train models
target = ["updrs_1", "updrs_2", "updrs_3", "updrs_4"]

def func(row,grps,label):
#     print(type(row['visit_month']))
#     print(row[['visit_id','visit_month']])
#     print(0 in [int(i) for i in grps['visit_month']])
#     print(6 in [int(i) for i in grps['visit_month']])
#     print(24 in [int(i) for i in grps['visit_month']])
    #print(row[['visit_month','patient_id',label]])
    
    if int(row['visit_month']+6) in [int(i) for i in grps['visit_month']]:
#         print('YES 6')
#         print(row[['visit_month','patient_id',label]])
        row[label+'_6'] = grps.loc[grps['visit_month'].astype(int)==int(row['visit_month']+6)][label]
    
    if int(row['visit_month']+12) in [int(i) for i in grps['visit_month']]:
#         print('YES 12')
#         print(row[['visit_month','patient_id',label]])
        row[label+'_12'] = grps.loc[grps['visit_month'].astype(int)==int(row['visit_month']+12)][label]
                                   
    if int(row['visit_month']+24) in [int(i) for i in grps['visit_month']]:
#         print('YES 24')
#         print(row[['visit_month','patient_id',label]])
        row[label+'_24'] = grps.loc[grps['visit_month'].astype(int)==int(row['visit_month']+24)][label]
#     print(row[['visit_id',label+'_6',label+'_12',label+'_24']])

    return row

# Loop through each label   
for label in target:
    
    # Merge the label 'visit_id', 'patient_id', 'visit_month' and label columns from `train_clinical` 
    # data frame to `pro_prep_df` data frame on the `visit_id` column.
    dataset_df = pro_pep_df.merge(train_clinical[['visit_id', 'patient_id', 'visit_month', label]], on = ['visit_id'], how = 'left')
    
    #print(dataset_df.head())
    # Drop null value label rows
    dataset_df = dataset_df.dropna(subset=[label])
    
    print(len(dataset_df))
    dataset_df[label+'_6'] = -1
    dataset_df[label+'_12']= -1
    dataset_df[label+'_24']= -1
    
    grps = dataset_df.groupby(['patient_id'])
    print(grps)
    grp1s = []
    for grp in grps:
#         print(grp)
        grp1 =grp[1]
#         print(type(grp1))
        grp1 = grp1.apply(lambda x: func(x,grp1,label),axis=1)
        grp1s.append(grp1)
#         print(grp)
    print(len(grp1s))
    #TODO - Data is in grps have to combine and seperate into mon6,12 and 24
    new_df = pd.concat(grp1s)
#     print(new_df.head())
    immediate = new_df.copy()
    mon6 = new_df.copy()
    mon12 = new_df.copy()
    mon24 = new_df.copy()
#     print(list(mon6['updrs_1_6'])[0])
    if label == 'updrs_1':
        mon6 = mon6[mon6['updrs_1_6'].astype(int)!= -1]
        mon12 = mon12[mon12['updrs_1_12'].astype(int) != -1]
        mon24 = mon24[mon24['updrs_1_24'].astype(int) != -1]
    if label == 'updrs_2':
        mon6 = mon6[mon6['updrs_2_6'].astype(int)!= -1]
        mon12 = mon12[mon12['updrs_2_12'].astype(int) != -1]
        mon24 = mon24[mon24['updrs_2_24'].astype(int) != -1]
    if label == 'updrs_3':
        mon6 = mon6[mon6['updrs_3_6'].astype(int)!= -1]
        mon12 = mon12[mon12['updrs_3_12'].astype(int) != -1]
        mon24 = mon24[mon24['updrs_3_24'].astype(int) != -1]
    if label == 'updrs_4':
        mon6 = mon6[mon6['updrs_4_6'].astype(int)!= -1]
        mon12 = mon12[mon12['updrs_4_12'].astype(int) != -1]
        mon24 = mon24[mon24['updrs_4_24'].astype(int) != -1]
#         print(mon6)
#     print(type(new_df['updrs_1_6'][0]))
    print(len(immediate),len(mon6),len(mon12),len(mon24))
    # Make a new copy of the FEATURES list we created previously. Add `label` to it.
    
    
    
    c=0
    for dataset in [immediate,mon6,mon12,mon24]:
        s = ''
        if c==0:
            s = ''
        elif c==1:
            s = '_6'
        elif c==2:
            s = '_12'
        else:
            s = '_24'
         
        dataset = dataset.dropna(subset=[label+s])
        feature_list = FEATURES.copy() 
        feature_list.append(label+s)
        dataset[label+s] = dataset[label+s].astype('float')
        print(type(dataset[label+s].iloc[0]))
        print((dataset[label+s].value_counts()))
        # Split the dataset into train and validation datasets.
        train_df, valid_df = split_dataset(dataset[feature_list].drop(columns=['visit_month']))
        print("{} examples in training, {} examples in testing.".format(len(train_df), len(valid_df)))

        # There's one more step required before we can train the model. 
        # We need to convert the datatset from Pandas format (pd.DataFrame)
        # into TensorFlow Datasets format (tf.data.Dataset).
        # TensorFlow Datasets is a high performance data loading library 
        # which is helpful when training neural networks with accelerators like GPUs and TPUs.
        print(label+s)
        
        
        
        train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label=(label+s), task = tfdf.keras.Task.REGRESSION)
        valid_ds = tfdf.keras.pd_dataframe_to_tf_dataset(valid_df, label=(label+s), task = tfdf.keras.Task.REGRESSION)

        # We will now create the Random Forest Tree Model with default settings. 
        # By default the model is set to train for a classification task. Since this is a regression problem,
        # we will specify the type of the task (tfdf.keras.Task.REGRESSION) as a parameter here.
        rf = tfdf.keras.RandomForestModel(task = tfdf.keras.Task.REGRESSION, verbose=0)
        rf.compile(metrics=["mse"])

        # Train the model.
        rf.fit(x=train_ds)

        # Store the model
        model_dict[label+s] = rf

        # Evaluate the trained model on the validation dataset and store the 
        # mse value in the `mse_dict`.
        inspector = rf.make_inspector()
        inspector.evaluation()
        evaluation = rf.evaluate(x=valid_ds,return_dict=True)
        mse_dict[label+s] = evaluation["mse"]  

        # Use the trained model to make predictions on the validation dataset.
        # Using these predictions, calculate and store the sMAPE value for this model.
        preds = rf.predict(valid_ds)
        smape_dict[label+s] = smape(valid_df[label+s].values.tolist(), preds.flatten())
        c +=1
# Out:
# 1068
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7bf602acb550>
# /tmp/ipykernel_34/3621051385.py:49: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for grp in grps:
# 248
# 1068 137 543 435
# <class 'numpy.float64'>
# 1.0     118
# 2.0     107
# 5.0      90
# 6.0      88
# 4.0      79
# 3.0      79
# 7.0      67
# 8.0      64
# 0.0      62
# 9.0      58
# 10.0     42
# 11.0     42
# 12.0     32
# 14.0     24
# 13.0     21
# 16.0     17
# 15.0     15
# 20.0     13
# 17.0     12
# 18.0     11
# 19.0      9
# 25.0      5
# 21.0      3
# 26.0      2
# 22.0      2
# 23.0      2
# 28.0      1
# 24.0      1
# 27.0      1
# 33.0      1
# Name: updrs_1, dtype: int64
# 853 examples in training, 215 examples in testing.
# updrs_1
# [INFO 2023-05-24T02:04:28.431773144+00:00 kernel.cc:1214] Loading model from path /tmp/tmpb3_4f622/model/ with prefix 98fcc1ee0471488e
# [INFO 2023-05-24T02:04:28.699369146+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 72156 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:04:28.699574732+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:04:28.700422185+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 23.0912
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 6.0     17
# 5.0     14
# 1.0     12
# 7.0     11
# 4.0     11
# 2.0      9
# 8.0      8
# 0.0      8
# 10.0     8
# 9.0      8
# 11.0     7
# 3.0      6
# 12.0     5
# 14.0     3
# 13.0     3
# 18.0     2
# 17.0     2
# 15.0     1
# 16.0     1
# 33.0     1
# Name: updrs_1_6, dtype: int64
# 108 examples in training, 29 examples in testing.
# updrs_1_6
# [INFO 2023-05-24T02:05:04.728982983+00:00 kernel.cc:1214] Loading model from path /tmp/tmpxqw8l6ff/model/ with prefix 108c340b2dc24620
# [INFO 2023-05-24T02:05:04.770500019+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 10020 node(s), and 1153 input feature(s).
# [INFO 2023-05-24T02:05:04.770826475+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:05:04.771644194+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 19.4069
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 1.0     56
# 5.0     45
# 2.0     43
# 4.0     42
# 7.0     38
# 8.0     38
# 3.0     37
# 6.0     37
# 0.0     36
# 9.0     30
# 11.0    26
# 10.0    22
# 12.0    17
# 13.0    12
# 20.0    11
# 14.0    11
# 16.0    11
# 15.0     9
# 19.0     5
# 18.0     5
# 17.0     3
# 25.0     2
# 21.0     2
# 23.0     1
# 27.0     1
# 28.0     1
# 24.0     1
# 22.0     1
# Name: updrs_1_12, dtype: int64
# 434 examples in training, 109 examples in testing.
# updrs_1_12
# [INFO 2023-05-24T02:05:51.241785569+00:00 kernel.cc:1214] Loading model from path /tmp/tmp6wm_sxo2/model/ with prefix 194e7573d40d4352
# [INFO 2023-05-24T02:05:51.391421726+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 39460 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:05:51.391731677+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:05:51.392566712+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 19.0479
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 1.0     45
# 2.0     38
# 6.0     36
# 5.0     35
# 4.0     34
# 7.0     32
# 3.0     30
# 8.0     27
# 0.0     23
# 9.0     23
# 10.0    15
# 11.0    13
# 14.0    12
# 13.0    11
# 12.0    10
# 15.0    10
# 16.0     9
# 19.0     8
# 17.0     6
# 20.0     5
# 18.0     4
# 21.0     3
# 23.0     1
# 27.0     1
# 22.0     1
# 24.0     1
# 25.0     1
# 26.0     1
# Name: updrs_1_24, dtype: int64
# 348 examples in training, 87 examples in testing.
# updrs_1_24
# [INFO 2023-05-24T02:06:32.603904508+00:00 kernel.cc:1214] Loading model from path /tmp/tmp8fofzqgb/model/ with prefix 789f91f0a7af4db5
# [INFO 2023-05-24T02:06:32.728605758+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 32086 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:06:32.728996137+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:06:32.729747274+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 24.4702
# 1/1 [==============================] - 2s 2s/step
# 1068
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7bf610b2d5d0>
# /tmp/ipykernel_34/3621051385.py:49: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for grp in grps:
# 248
# 1068 137 543 435
# <class 'numpy.float64'>
# 0.0     263
# 2.0      85
# 3.0      76
# 8.0      65
# 5.0      64
# 1.0      63
# 4.0      62
# 7.0      55
# 6.0      50
# 9.0      39
# 10.0     38
# 13.0     29
# 15.0     29
# 11.0     28
# 14.0     23
# 12.0     22
# 16.0     12
# 18.0     12
# 20.0      9
# 17.0      8
# 19.0      7
# 22.0      6
# 21.0      6
# 23.0      5
# 26.0      3
# 24.0      3
# 27.0      3
# 28.0      2
# 29.0      1
# Name: updrs_2, dtype: int64
# 874 examples in training, 194 examples in testing.
# updrs_2
# [INFO 2023-05-24T02:07:56.111629062+00:00 kernel.cc:1214] Loading model from path /tmp/tmplujb7oo6/model/ with prefix e9eb0789e1244a37
# [INFO 2023-05-24T02:07:56.368831547+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 68304 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:07:56.369035271+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:07:56.370041095+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 25.0222
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 2.0     15
# 7.0     15
# 8.0     13
# 3.0     11
# 9.0     11
# 4.0      9
# 5.0      9
# 10.0     8
# 1.0      7
# 6.0      6
# 14.0     6
# 20.0     4
# 13.0     4
# 0.0      3
# 11.0     3
# 12.0     3
# 19.0     2
# 15.0     1
# 27.0     1
# 16.0     1
# 28.0     1
# 23.0     1
# 22.0     1
# 21.0     1
# 24.0     1
# Name: updrs_2_6, dtype: int64
# 110 examples in training, 27 examples in testing.
# updrs_2_6
# [INFO 2023-05-24T02:08:31.766512421+00:00 kernel.cc:1214] Loading model from path /tmp/tmpbz3zgpe5/model/ with prefix 85e266d50e7a4cf8
# [INFO 2023-05-24T02:08:31.809021521+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 10156 node(s), and 1135 input feature(s).
# [INFO 2023-05-24T02:08:31.809323905+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:08:31.810121965+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 40.7863
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 0.0     141
# 3.0      41
# 8.0      36
# 2.0      35
# 4.0      35
# 5.0      32
# 7.0      26
# 9.0      24
# 1.0      24
# 10.0     23
# 6.0      22
# 13.0     16
# 15.0     16
# 14.0     13
# 12.0     11
# 11.0     10
# 16.0      7
# 18.0      6
# 17.0      5
# 19.0      4
# 23.0      3
# 22.0      3
# 20.0      3
# 26.0      2
# 21.0      2
# 24.0      1
# 28.0      1
# 27.0      1
# Name: updrs_2_12, dtype: int64
# 429 examples in training, 114 examples in testing.
# updrs_2_12
# [INFO 2023-05-24T02:09:13.482406562+00:00 kernel.cc:1214] Loading model from path /tmp/tmpeacewlnj/model/ with prefix 2ae78c5d6a8a401d
# [INFO 2023-05-24T02:09:13.6155788+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 35212 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:09:13.615903172+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:09:13.616684998+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 25.7504
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 0.0     107
# 5.0      31
# 8.0      29
# 1.0      28
# 3.0      27
# 4.0      26
# 2.0      25
# 6.0      21
# 7.0      20
# 9.0      16
# 11.0     13
# 10.0     13
# 14.0     11
# 12.0     11
# 13.0     10
# 15.0     10
# 16.0      7
# 18.0      7
# 17.0      4
# 21.0      3
# 23.0      3
# 19.0      3
# 20.0      3
# 26.0      2
# 22.0      2
# 24.0      1
# 27.0      1
# 29.0      1
# Name: updrs_2_24, dtype: int64
# 349 examples in training, 86 examples in testing.
# updrs_2_24
# [INFO 2023-05-24T02:09:55.881639337+00:00 kernel.cc:1214] Loading model from path /tmp/tmprneg9utu/model/ with prefix ba5fbd38aae64c37
# [INFO 2023-05-24T02:09:55.994653496+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 29482 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:09:55.995128998+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:09:55.995931454+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 37.0614
# 1/1 [==============================] - 2s 2s/step
# 1058
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7bf4fa699450>
# /tmp/ipykernel_34/3621051385.py:49: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for grp in grps:
# 248
# 1058 132 537 426
# <class 'numpy.float64'>
# 0.0     187
# 1.0      47
# 2.0      41
# 18.0     31
# 22.0     28
#        ...
# 63.0      1
# 60.0      1
# 78.0      1
# 61.0      1
# 58.0      1
# Name: updrs_3, Length: 64, dtype: int64
# 837 examples in training, 221 examples in testing.
# updrs_3
# [INFO 2023-05-24T02:11:15.781577755+00:00 kernel.cc:1214] Loading model from path /tmp/tmplidptnzs/model/ with prefix a4fd5aab5dfc411a
# [INFO 2023-05-24T02:11:16.062020066+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 72996 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:11:16.062215851+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:11:16.062999437+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 150.7980
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 18.0    9
# 0.0     6
# 26.0    6
# 27.0    6
# 25.0    5
# 24.0    5
# 15.0    5
# 12.0    4
# 13.0    4
# 33.0    4
# 34.0    4
# 20.0    4
# 11.0    4
# 17.0    4
# 38.0    3
# 21.0    3
# 7.0     3
# 22.0    3
# 39.0    3
# 32.0    3
# 16.0    3
# 28.0    3
# 19.0    3
# 8.0     3
# 51.0    2
# 47.0    2
# 43.0    2
# 35.0    2
# 41.0    2
# 9.0     2
# 31.0    2
# 36.0    2
# 5.0     2
# 23.0    2
# 14.0    1
# 3.0     1
# 46.0    1
# 40.0    1
# 56.0    1
# 68.0    1
# 30.0    1
# 29.0    1
# 10.0    1
# 44.0    1
# 52.0    1
# 6.0     1
# Name: updrs_3_6, dtype: int64
# 99 examples in training, 33 examples in testing.
# updrs_3_6
# [INFO 2023-05-24T02:11:51.722469571+00:00 kernel.cc:1214] Loading model from path /tmp/tmprz56_z73/model/ with prefix 1ee33ca98af044f3
# [INFO 2023-05-24T02:11:51.760486431+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 9130 node(s), and 1116 input feature(s).
# [INFO 2023-05-24T02:11:51.760959076+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:11:51.761904992+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 140.2836
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 0.0     98
# 1.0     28
# 18.0    18
# 2.0     18
# 26.0    18
# 28.0    16
# 3.0     16
# 19.0    13
# 27.0    12
# 17.0    12
# 20.0    12
# 11.0    12
# 10.0    12
# 15.0    12
# 21.0    12
# 14.0    11
# 22.0    11
# 24.0    11
# 13.0    10
# 36.0    10
# 4.0      9
# 31.0     9
# 7.0      9
# 16.0     8
# 5.0      8
# 9.0      8
# 39.0     8
# 32.0     8
# 35.0     8
# 38.0     7
# 33.0     7
# 12.0     7
# 37.0     7
# 8.0      6
# 30.0     6
# 41.0     6
# 23.0     5
# 29.0     5
# 43.0     4
# 34.0     4
# 6.0      4
# 51.0     4
# 46.0     3
# 40.0     3
# 44.0     2
# 47.0     2
# 42.0     2
# 25.0     2
# 59.0     2
# 52.0     2
# 68.0     1
# 50.0     1
# 49.0     1
# 63.0     1
# 60.0     1
# 67.0     1
# 78.0     1
# 61.0     1
# 45.0     1
# 48.0     1
# Name: updrs_3_12, dtype: int64
# 405 examples in training, 132 examples in testing.
# updrs_3_12
# [INFO 2023-05-24T02:12:43.708090327+00:00 kernel.cc:1214] Loading model from path /tmp/tmpg3cf2jw4/model/ with prefix 5273809fa25343e2
# [INFO 2023-05-24T02:12:43.843305944+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 35632 node(s), and 1195 input feature(s).
# [INFO 2023-05-24T02:12:43.843609253+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:12:43.844455576+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 195.8560
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 0.0     76
# 1.0     24
# 2.0     20
# 28.0    15
# 3.0     12
# 22.0    12
# 18.0    11
# 9.0     10
# 32.0    10
# 11.0     9
# 20.0     9
# 15.0     9
# 21.0     9
# 24.0     9
# 5.0      8
# 30.0     8
# 26.0     8
# 31.0     8
# 37.0     8
# 13.0     8
# 38.0     8
# 41.0     7
# 10.0     7
# 14.0     7
# 17.0     7
# 39.0     7
# 19.0     7
# 46.0     6
# 35.0     6
# 51.0     5
# 6.0      5
# 29.0     5
# 36.0     5
# 27.0     5
# 7.0      5
# 12.0     4
# 16.0     4
# 23.0     4
# 44.0     3
# 25.0     3
# 43.0     3
# 4.0      3
# 48.0     3
# 34.0     3
# 49.0     2
# 33.0     2
# 59.0     2
# 42.0     2
# 8.0      2
# 55.0     2
# 40.0     1
# 66.0     1
# 47.0     1
# 52.0     1
# 63.0     1
# 56.0     1
# 67.0     1
# 78.0     1
# 50.0     1
# Name: updrs_3_24, dtype: int64
# 348 examples in training, 78 examples in testing.
# updrs_3_24
# [INFO 2023-05-24T02:13:26.104125876+00:00 kernel.cc:1214] Loading model from path /tmp/tmp5sa9gio6/model/ with prefix e3af1f63c4844d39
# [INFO 2023-05-24T02:13:26.222190311+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 30864 node(s), and 1194 input feature(s).
# [INFO 2023-05-24T02:13:26.222426939+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:13:26.223192879+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 210.8524
# 1/1 [==============================] - 2s 2s/step
# 569
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7bf50d6f0bb0>
# /tmp/ipykernel_34/3621051385.py:49: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for grp in grps:
# 180
# 569 7 294 223
# <class 'numpy.float64'>
# 0.0     344
# 4.0      36
# 3.0      35
# 5.0      33
# 2.0      29
# 1.0      23
# 6.0      17
# 7.0      15
# 8.0      11
# 9.0       8
# 10.0      5
# 13.0      4
# 12.0      3
# 14.0      2
# 11.0      2
# 20.0      1
# 16.0      1
# Name: updrs_4, dtype: int64
# 456 examples in training, 113 examples in testing.
# updrs_4
# [INFO 2023-05-24T02:14:32.481483279+00:00 kernel.cc:1214] Loading model from path /tmp/tmp46k3mxwd/model/ with prefix f02ef5325f794adc
# [INFO 2023-05-24T02:14:32.581716415+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 25080 node(s), and 1192 input feature(s).
# [INFO 2023-05-24T02:14:32.582062722+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:14:32.582861698+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 10.1690
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 0.0    5
# 1.0    1
# 7.0    1
# Name: updrs_4_6, dtype: int64
# 6 examples in training, 1 examples in testing.
# updrs_4_6
# [INFO 2023-05-24T02:15:24.924589886+00:00 kernel.cc:1214] Loading model from path /tmp/tmpggmzxb7n/model/ with prefix 1773cb99cc554742
# [WARNING 2023-05-24T02:15:24.927346372+00:00 utils.cc:73] The model does not have any input features i.e. the model is constant and will always return the same prediction.
# [INFO 2023-05-24T02:15:24.928132882+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 300 node(s), and 0 input feature(s).
# [INFO 2023-05-24T02:15:24.928227995+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:15:24.928613802+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 1.0000
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 0.0     158
# 3.0      22
# 4.0      21
# 5.0      21
# 2.0      16
# 1.0      12
# 6.0      11
# 7.0      11
# 8.0       6
# 12.0      3
# 9.0       3
# 13.0      3
# 10.0      2
# 14.0      2
# 20.0      1
# 11.0      1
# 16.0      1
# Name: updrs_4_12, dtype: int64
# 253 examples in training, 41 examples in testing.
# updrs_4_12
# [INFO 2023-05-24T02:16:03.176811705+00:00 kernel.cc:1214] Loading model from path /tmp/tmp6mti5o6h/model/ with prefix 1e3d12dcd4c449c2
# [INFO 2023-05-24T02:16:03.239929521+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 15838 node(s), and 1183 input feature(s).
# [INFO 2023-05-24T02:16:03.240206564+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:16:03.240906543+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 8.5586
# 1/1 [==============================] - 2s 2s/step
# <class 'numpy.float64'>
# 0.0     108
# 4.0      20
# 5.0      18
# 1.0      17
# 3.0      15
# 2.0      12
# 7.0       8
# 6.0       7
# 8.0       4
# 10.0      3
# 9.0       3
# 13.0      3
# 14.0      2
# 20.0      1
# 12.0      1
# 16.0      1
# Name: updrs_4_24, dtype: int64
# 177 examples in training, 46 examples in testing.
# updrs_4_24
# [INFO 2023-05-24T02:16:40.310561257+00:00 kernel.cc:1214] Loading model from path /tmp/tmpfs95omtr/model/ with prefix 4dc50ade00db40fb
# [INFO 2023-05-24T02:16:40.35951339+00:00 decision_forest.cc:661] Model loaded with 300 root(s), 12092 node(s), and 1168 input feature(s).
# [INFO 2023-05-24T02:16:40.359715094+00:00 abstract_model.cc:1311] Engine "RandomForestOptPred" built
# [INFO 2023-05-24T02:16:40.360496747+00:00 kernel.cc:1046] Use fast generic engine
# 1/1 [==============================] - 4s 4s/step - loss: 0.0000e+00 - mse: 10.8950
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# # Inspect the Mean Squared Error(MSE) scores of the models.

# %%
for name, value in mse_dict.items():
  print(f"label {name}: mse {value:.4f}")

print("\nAverage mse", sum(mse_dict.values())/16)
# Out:
# label updrs_1: mse 23.0912
# label updrs_1_6: mse 19.4069
# label updrs_1_12: mse 19.0479
# label updrs_1_24: mse 24.4702
# label updrs_2: mse 25.0222
# label updrs_2_6: mse 40.7863
# label updrs_2_12: mse 25.7504
# label updrs_2_24: mse 37.0614
# label updrs_3: mse 150.7980
# label updrs_3_6: mse 140.2836
# label updrs_3_12: mse 195.8560
# label updrs_3_24: mse 210.8524
# label updrs_4: mse 10.1690
# label updrs_4_6: mse 1.0000
# label updrs_4_12: mse 8.5586
# label updrs_4_24: mse 10.8950
#
# Average mse 58.94057458639145

# %% [markdown]
# # Inspect the sMAPE scores of the models

# %%
for name, value in smape_dict.items():
  print(f"label {name}: sMAPE {value:.4f}")

print("\nAverage sMAPE", sum(smape_dict.values())/16)
# Out:
# label updrs_1: sMAPE 66.8194
# label updrs_1_6: sMAPE 65.9829
# label updrs_1_12: sMAPE 59.2491
# label updrs_1_24: sMAPE 66.7728
# label updrs_2: sMAPE 88.7024
# label updrs_2_6: sMAPE 60.2115
# label updrs_2_12: sMAPE 87.3903
# label updrs_2_24: sMAPE 104.0687
# label updrs_3: sMAPE 88.8972
# label updrs_3_6: sMAPE 51.4807
# label updrs_3_12: sMAPE 85.7923
# label updrs_3_24: sMAPE 89.4654
# label updrs_4: sMAPE 155.8028
# label updrs_4_6: sMAPE 200.0000
# label updrs_4_12: sMAPE 134.6955
# label updrs_4_24: sMAPE 136.2908
#
# Average sMAPE 96.35135944968191

# %% [markdown]
# # Visualize the model
#
# One benefit of tree-based models is that we can easily visualize them. The default number of trees used in the Random Forests is 300.
#
# Let us pick one model from `model_dict` and select a tree to display below.

# %%
# Let us use the model for the label `updrs_1` for this purpose
tfdf.model_plotter.plot_model_in_colab(model_dict['updrs_1'], tree_idx=0, max_depth=3)

# %% [markdown]
# # Evaluate the model on the Out of bag (OOB) data and the validation dataset
#
# Before training the dataset we have manually seperated 20% of the dataset for validation named as `valid_ds`.
#
# We can also use Out of bag (OOB) score to validate our RandomForestModel.
# To train a Random Forest Model, a set of random samples from training set are choosen by the algorithm and the rest of the samples are used to finetune the model.The subset of data that is not chosen is known as Out of bag data (OOB).
# OOB score is computed on the OOB data.
#
# Read more about OOB data [here](https://developers.google.com/machine-learning/decision-forests/out-of-bag).
#
# The training logs show the Root Mean Squared Error (RMSE) evaluated on the out-of-bag dataset according to the number of trees in the model. Let us plot this.
#
# Note: Smaller values are better for this hyperparameter.
#
# Let us pick one model from `model_dict` dict and plot the OOB evaluation accuracies.

# %%
import matplotlib.pyplot as plt

# Let us use the model for the label `updrs_1` for this purpose
logs = model_dict['updrs_1'].make_inspector().training_logs()
plt.plot([log.num_trees for log in logs], [log.evaluation.rmse for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("MSE (out-of-bag)")
plt.show()

# %% [markdown]
# # Variable importances
#
# Variable importances generally indicate how much a feature contributes to the model predictions or quality. There are several ways to identify important features using TensorFlow Decision Forests. Let us pick one model from models dict and inspect it.
#
# Let us list the available Variable Importances for Decision Trees:

# %%
# Let us use the model for the label `updrs_1` for this purpose
inspector = model_dict['updrs_1'].make_inspector()

print(f"Available variable importances:")
for importance in inspector.variable_importances().keys():
  print("\t", importance)

# %% [markdown]
# As an example, let us display the important features for the Variable Importance NUM_AS_ROOT.
#
# The larger the importance score for NUM_AS_ROOT, the more impact it has on the outcome of the model for Question 1(i.e., model\["0-4_1"\]).
#
# By default, the list is sorted from the most important to the least. From the output you can infer that the feature at the top of the list is used as the root node in most number of trees in the gradient boosted trees  than any other feature.

# %%
# Each line is: (feature name, (index of the feature), importance score)
inspector.variable_importances()["NUM_AS_ROOT"]

# %% [markdown]
# # Submission

# %%
import amp_pd_peptide_310
env = amp_pd_peptide_310.make_env()   # initialize the environment
iter_test = env.iter_test()

# %%
def get_predictions(test_df, test_ds, model_dict):

    # Target labels
    target = ["updrs_1", "updrs_2", "updrs_3", "updrs_4"]
    temp = test_df[FEATURES].copy()
    
    # Filter out all the 0 value columns before predicting
    mask = test_df[FEATURES].sum(axis=1) != 0
    new_test_df = temp.loc[mask]
    test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(new_test_df, task = tfdf.keras.Task.REGRESSION)
    for u in target:
        test_df['result_' + str(u)] = 0
        if u != 'updrs_4':
            print(model_dict[u])
            test_df.loc[mask, 'result_' + str(u)] = model_dict[u].predict(test_ds)
    
    # Format for final submission
    result = pd.DataFrame()

    for m in [0, 6, 12, 24]:
        for u in [1, 2, 3, 4]:

            temp = test_df[["visit_id", "result_updrs_" + str(u)]].copy()
            temp["prediction_id"] = temp["visit_id"] + "_updrs_" + str(u) + "_plus_" + str(m) + "_months"
            temp["rating"] = temp["result_updrs_" + str(u)]
            temp = temp [['prediction_id', 'rating']]

            result = result.append(temp)            
    result = result.drop_duplicates(subset=['prediction_id', 'rating'])

    return result

# %%
# Reference: https://www.kaggle.com/code/xarispanagiotopoulos/linearregression-xgb/notebook

for (test, test_peptides, test_proteins, sample_submission) in iter_test:
    pro_pep_df = prepare_dataset(test_proteins, test_peptides)


    test_proteins = test_proteins.pivot(index=['visit_id', 'visit_month', 'patient_id'], 
              columns='UniProt', values='NPX').reset_index().rename_axis(None, axis=1).drop(columns=['visit_month', 'patient_id'])
    merged_df = test.merge(test_proteins, how='left', on='visit_id')

    test_df = test.merge(pro_pep_df, how='left', on='visit_id')
    
    # Add all the missing columns from FEATURES list and set the values as 0
    for col in FEATURES:
        if col not in test_df.columns:
            test_df[col] = 0
    test_df = test_df[['visit_id', 'patient_id'] + FEATURES]

    test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, task = tfdf.keras.Task.REGRESSION)
    result = get_predictions(test_df, valid_ds, model_dict)
    print(result)

    env.predict(result)
